# %%
from urllib.request import urlopen
import json


response = urlopen('https://api.openf1.org/v1/laps?session_key=latest&driver_number=55')
data = json.loads(response.read().decode('utf-8'))


data
# Out:
# [{'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 284,
#   'i2_speed': 272,
#   'st_speed': 321,
#   'date_start': None,
#   'lap_duration': None,
#   'is_pit_out_lap': False,
#   'duration_sector_1': None,
#   'duration_sector_2': 32.28,
#   'duration_sector_3': 43.813,
#   'segments_sector_1': [2064, 2049, 2049, 2049, 2049, 2049, 2049],
#   'segments_sector_2': [2049, 2049, 2049, 2049, 2049, 2049],
#   'segments_sector_3': [2049, 2048, 2048, 2048, 2049, 2049, 2049, 2049, 2049],
#   'lap_number': 1},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 279,
#   'i2_speed': 271,
#   'st_speed': 336,
#   'date_start': '2025-03-23T07:05:26.472000+00:00',
#   'lap_duration': 99.718,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.361,
#   'duration_sector_2': 30.511,
#   'duration_sector_3': 42.846,
#   'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2048, 2049, 2049, 2049],
#   'segments_sector_3': [2049, 2048, 2048, 2048, 2049, 2049, 2049, 2049, 2049],
#   'lap_number': 2},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 275,
#   'i2_speed': 272,
#   'st_speed': 335,
#   'date_start': '2025-03-23T07:07:06.121000+00:00',
#   'lap_duration': 99.27,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.29,
#   'duration_sector_2': 30.258,
#   'duration_sector_3': 42.722,
#   'segments_sector_1': [None, 2049, 2049, 2048, 2049, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2049, 2049, 2048, 2048],
#   'segments_sector_3': [2049, 2048, 2049, 2048, 2049, 2049, 2049, 2049, 2048],
#   'lap_number': 3},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 276,
#   'i2_speed': 270,
#   'st_speed': 334,
#   'date_start': '2025-03-23T07:08:45.400000+00:00',
#   'lap_duration': 98.789,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.343,
#   'duration_sector_2': 30.062,
#   'duration_sector_3': 42.384,
#   'segments_sector_1': [2048, 2048, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2048, 2049, 2049, 2049],
#   'segments_sector_3': [2049, 2048, 2048, 2048, 2049, 2051, 2049, 2049, 2049],
#   'lap_number': 4},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': None,
#   'i2_speed': 270,
#   'st_speed': 335,
#   'date_start': '2025-03-23T07:10:24.149000+00:00',
#   'lap_duration': 98.787,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.386,
#   'duration_sector_2': 30.262,
#   'duration_sector_3': 42.139,
#   'segments_sector_1': [None, 2048, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2049, 2049, 2048, 2048, 2049, 2048],
#   'lap_number': 5},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': None,
#   'i2_speed': 269,
#   'st_speed': 335,
#   'date_start': '2025-03-23T07:12:03.037000+00:00',
#   'lap_duration': 99.179,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.339,
#   'duration_sector_2': 30.324,
#   'duration_sector_3': 42.516,
#   'segments_sector_1': [None, 2049, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2049, 2049, 2048, 2048, 2049, 2048],
#   'lap_number': 6},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 275,
#   'i2_speed': 272,
#   'st_speed': 334,
#   'date_start': '2025-03-23T07:13:42.193000+00:00',
#   'lap_duration': 99.075,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.41,
#   'duration_sector_2': 30.308,
#   'duration_sector_3': 42.357,
#   'segments_sector_1': [2049, 2049, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2049, 2048, 2048, 2049, 2049, 2048, 2048, 2048, 2048],
#   'lap_number': 7},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': None,
#   'i2_speed': 269,
#   'st_speed': 333,
#   'date_start': '2025-03-23T07:15:21.255000+00:00',
#   'lap_duration': 99.548,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.491,
#   'duration_sector_2': 30.488,
#   'duration_sector_3': 42.569,
#   'segments_sector_1': [2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2049],
#   'lap_number': 8},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 276,
#   'i2_speed': 271,
#   'st_speed': 335,
#   'date_start': '2025-03-23T07:17:00.796000+00:00',
#   'lap_duration': 99.237,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.463,
#   'duration_sector_2': 30.376,
#   'duration_sector_3': 42.398,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2049, 2049, 2048, 2048, 2048, 2048],
#   'lap_number': 9},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 274,
#   'i2_speed': 271,
#   'st_speed': 336,
#   'date_start': '2025-03-23T07:18:40.004000+00:00',
#   'lap_duration': 99.225,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.551,
#   'duration_sector_2': 30.317,
#   'duration_sector_3': 42.357,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2049, 2048],
#   'lap_number': 10},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 275,
#   'i2_speed': 270,
#   'st_speed': 333,
#   'date_start': '2025-03-23T07:20:19.255000+00:00',
#   'lap_duration': 99.057,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.43,
#   'duration_sector_2': 30.192,
#   'duration_sector_3': 42.435,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048],
#   'lap_number': 11},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 276,
#   'i2_speed': 270,
#   'st_speed': 315,
#   'date_start': '2025-03-23T07:21:58.324000+00:00',
#   'lap_duration': 99.643,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.47,
#   'duration_sector_2': 30.367,
#   'duration_sector_3': 42.806,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2049, 2048, 2048, 2048, 2048, 2048, 2049, 2049, 0],
#   'lap_number': 12},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 277,
#   'i2_speed': 270,
#   'st_speed': 314,
#   'date_start': '2025-03-23T07:23:37.881000+00:00',
#   'lap_duration': 99.276,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.621,
#   'duration_sector_2': 30.114,
#   'duration_sector_3': 42.541,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2049],
#   'lap_number': 13},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 276,
#   'i2_speed': 271,
#   'st_speed': 316,
#   'date_start': '2025-03-23T07:25:17.061000+00:00',
#   'lap_duration': 99.023,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.624,
#   'duration_sector_2': 29.964,
#   'duration_sector_3': 42.435,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 14},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 279,
#   'i2_speed': 270,
#   'st_speed': 333,
#   'date_start': '2025-03-23T07:26:56.245000+00:00',
#   'lap_duration': 99.451,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.458,
#   'duration_sector_2': 30.23,
#   'duration_sector_3': 42.763,
#   'segments_sector_1': [None, 2048, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2049, 2048, 2048, 2049, 2048, 0],
#   'lap_number': 15},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 277,
#   'i2_speed': 272,
#   'st_speed': 327,
#   'date_start': '2025-03-23T07:28:35.723000+00:00',
#   'lap_duration': 99.094,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.468,
#   'duration_sector_2': 30.218,
#   'duration_sector_3': 42.408,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2049, 2064],
#   'lap_number': 16},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 274,
#   'i2_speed': 269,
#   'st_speed': 316,
#   'date_start': '2025-03-23T07:30:14.750000+00:00',
#   'lap_duration': 105.121,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.488,
#   'duration_sector_2': 30.218,
#   'duration_sector_3': 48.415,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2049, 2049, 2049, 2048, 2048, 2048, 2048, 2048, 2049],
#   'lap_number': 17},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 275,
#   'i2_speed': 265,
#   'st_speed': 315,
#   'date_start': '2025-03-23T07:31:59.836000+00:00',
#   'lap_duration': 116.375,
#   'is_pit_out_lap': True,
#   'duration_sector_1': 44.812,
#   'duration_sector_2': 29.629,
#   'duration_sector_3': 41.934,
#   'segments_sector_1': [2064, 2064, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2048, 2049, 2049, 2049],
#   'segments_sector_3': [2049, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 18},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': None,
#   'i2_speed': 273,
#   'st_speed': 321,
#   'date_start': '2025-03-23T07:33:56.425000+00:00',
#   'lap_duration': 97.924,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.217,
#   'duration_sector_2': 29.504,
#   'duration_sector_3': 42.203,
#   'segments_sector_1': [2048, 2048, 2049, 2048, 2049, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2048, 2049, 2048, 2049],
#   'segments_sector_3': [2048, 2048, 2048, 2049, 2049, 2048, 2049, 2048, 0],
#   'lap_number': 19},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 276,
#   'i2_speed': 273,
#   'st_speed': 333,
#   'date_start': '2025-03-23T07:35:34.218000+00:00',
#   'lap_duration': 98.739,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.411,
#   'duration_sector_2': 30.18,
#   'duration_sector_3': 42.148,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048, 2048],
#   'lap_number': 20},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 277,
#   'i2_speed': 271,
#   'st_speed': 315,
#   'date_start': '2025-03-23T07:37:12.942000+00:00',
#   'lap_duration': 98.151,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.276,
#   'duration_sector_2': 29.718,
#   'duration_sector_3': 42.157,
#   'segments_sector_1': [None, 2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048, 2048],
#   'lap_number': 21},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': None,
#   'i2_speed': 271,
#   'st_speed': 317,
#   'date_start': '2025-03-23T07:38:51.165000+00:00',
#   'lap_duration': 98.143,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.195,
#   'duration_sector_2': 29.729,
#   'duration_sector_3': 42.219,
#   'segments_sector_1': [None, 2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 22},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 281,
#   'i2_speed': 272,
#   'st_speed': 334,
#   'date_start': '2025-03-23T07:40:29.234000+00:00',
#   'lap_duration': 97.758,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 25.976,
#   'duration_sector_2': 29.781,
#   'duration_sector_3': 42.001,
#   'segments_sector_1': [None, 2048, 2049, 2051, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 0],
#   'lap_number': 23},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 285,
#   'i2_speed': 271,
#   'st_speed': 314,
#   'date_start': '2025-03-23T07:42:07.065000+00:00',
#   'lap_duration': 98.047,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 25.919,
#   'duration_sector_2': 29.885,
#   'duration_sector_3': 42.243,
#   'segments_sector_1': [None, 2048, 2049, 2048, 2048, 2048, 2049],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 24},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 274,
#   'i2_speed': 268,
#   'st_speed': 315,
#   'date_start': '2025-03-23T07:43:45.071000+00:00',
#   'lap_duration': 98.187,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.119,
#   'duration_sector_2': 29.7,
#   'duration_sector_3': 42.368,
#   'segments_sector_1': [None, 2048, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 25},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 275,
#   'i2_speed': 271,
#   'st_speed': 316,
#   'date_start': '2025-03-23T07:45:23.316000+00:00',
#   'lap_duration': 98.346,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.208,
#   'duration_sector_2': 29.654,
#   'duration_sector_3': 42.484,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048, 0],
#   'lap_number': 26},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 276,
#   'i2_speed': 272,
#   'st_speed': 316,
#   'date_start': '2025-03-23T07:47:01.618000+00:00',
#   'lap_duration': 98.083,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.087,
#   'duration_sector_2': 29.563,
#   'duration_sector_3': 42.433,
#   'segments_sector_1': [None, 2048, 2048, 2051, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 27},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 277,
#   'i2_speed': 273,
#   'st_speed': 316,
#   'date_start': '2025-03-23T07:48:39.638000+00:00',
#   'lap_duration': 98.196,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.27,
#   'duration_sector_2': 29.706,
#   'duration_sector_3': 42.22,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2049],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2049],
#   'lap_number': 28},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 276,
#   'i2_speed': 271,
#   'st_speed': 315,
#   'date_start': '2025-03-23T07:50:17.951000+00:00',
#   'lap_duration': 97.951,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.201,
#   'duration_sector_2': 29.676,
#   'duration_sector_3': 42.074,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2049],
#   'lap_number': 29},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 277,
#   'i2_speed': 273,
#   'st_speed': 315,
#   'date_start': '2025-03-23T07:51:55.914000+00:00',
#   'lap_duration': 97.762,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.008,
#   'duration_sector_2': 29.646,
#   'duration_sector_3': 42.108,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 30},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 276,
#   'i2_speed': 272,
#   'st_speed': 315,
#   'date_start': '2025-03-23T07:53:33.621000+00:00',
#   'lap_duration': 98.252,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.22,
#   'duration_sector_2': 29.684,
#   'duration_sector_3': 42.348,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048, 2048],
#   'lap_number': 31},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 279,
#   'i2_speed': 274,
#   'st_speed': 315,
#   'date_start': '2025-03-23T07:55:11.947000+00:00',
#   'lap_duration': 97.904,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.113,
#   'duration_sector_2': 29.59,
#   'duration_sector_3': 42.201,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 32},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 276,
#   'i2_speed': 272,
#   'st_speed': 314,
#   'date_start': '2025-03-23T07:56:49.734000+00:00',
#   'lap_duration': 97.783,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.076,
#   'duration_sector_2': 29.684,
#   'duration_sector_3': 42.023,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 33},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 277,
#   'i2_speed': 273,
#   'st_speed': 316,
#   'date_start': '2025-03-23T07:58:27.529000+00:00',
#   'lap_duration': 98.061,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.226,
#   'duration_sector_2': 29.676,
#   'duration_sector_3': 42.159,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 34},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 276,
#   'i2_speed': 271,
#   'st_speed': 316,
#   'date_start': '2025-03-23T08:00:05.536000+00:00',
#   'lap_duration': 98.752,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.116,
#   'duration_sector_2': 29.573,
#   'duration_sector_3': 43.063,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 0],
#   'lap_number': 35},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 273,
#   'i2_speed': 265,
#   'st_speed': 314,
#   'date_start': '2025-03-23T08:01:44.314000+00:00',
#   'lap_duration': 98.984,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.375,
#   'duration_sector_2': 30.408,
#   'duration_sector_3': 42.201,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2049],
#   'lap_number': 36},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 276,
#   'i2_speed': 269,
#   'st_speed': 314,
#   'date_start': '2025-03-23T08:03:23.297000+00:00',
#   'lap_duration': 97.803,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.179,
#   'duration_sector_2': 29.455,
#   'duration_sector_3': 42.169,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 37},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 275,
#   'i2_speed': 273,
#   'st_speed': 313,
#   'date_start': '2025-03-23T08:05:01.140000+00:00',
#   'lap_duration': 97.364,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.006,
#   'duration_sector_2': 29.428,
#   'duration_sector_3': 41.93,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 38},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 279,
#   'i2_speed': 274,
#   'st_speed': 314,
#   'date_start': '2025-03-23T08:06:38.544000+00:00',
#   'lap_duration': 97.18,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 25.776,
#   'duration_sector_2': 29.362,
#   'duration_sector_3': 42.042,
#   'segments_sector_1': [None, 2048, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2049],
#   'lap_number': 39},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 274,
#   'i2_speed': 272,
#   'st_speed': 315,
#   'date_start': '2025-03-23T08:08:15.716000+00:00',
#   'lap_duration': 97.55,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.062,
#   'duration_sector_2': 29.427,
#   'duration_sector_3': 42.061,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 40},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 276,
#   'i2_speed': 272,
#   'st_speed': 313,
#   'date_start': '2025-03-23T08:09:53.200000+00:00',
#   'lap_duration': 97.462,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.05,
#   'duration_sector_2': 29.4,
#   'duration_sector_3': 42.012,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 41},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': None,
#   'i2_speed': 272,
#   'st_speed': 313,
#   'date_start': '2025-03-23T08:11:30.780000+00:00',
#   'lap_duration': 97.379,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.092,
#   'duration_sector_2': 29.337,
#   'duration_sector_3': 41.95,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 42},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 275,
#   'i2_speed': 269,
#   'st_speed': 314,
#   'date_start': '2025-03-23T08:13:08.127000+00:00',
#   'lap_duration': 98.879,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.645,
#   'duration_sector_2': 29.912,
#   'duration_sector_3': 42.322,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 0, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048, 2048],
#   'lap_number': 43},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 274,
#   'i2_speed': 271,
#   'st_speed': 313,
#   'date_start': '2025-03-23T08:14:46.924000+00:00',
#   'lap_duration': 97.55,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.193,
#   'duration_sector_2': 29.158,
#   'duration_sector_3': 42.199,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2049, 2048, 2049],
#   'segments_sector_3': [2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 44},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 278,
#   'i2_speed': 275,
#   'st_speed': 313,
#   'date_start': '2025-03-23T08:16:24.467000+00:00',
#   'lap_duration': 97.193,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.041,
#   'duration_sector_2': 29.183,
#   'duration_sector_3': 41.969,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 45},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 275,
#   'i2_speed': 272,
#   'st_speed': 313,
#   'date_start': '2025-03-23T08:18:01.703000+00:00',
#   'lap_duration': 97.355,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 25.958,
#   'duration_sector_2': 29.246,
#   'duration_sector_3': 42.151,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048, 2049],
#   'lap_number': 46},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': None,
#   'i2_speed': 271,
#   'st_speed': 313,
#   'date_start': '2025-03-23T08:19:39.221000+00:00',
#   'lap_duration': 97.144,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.002,
#   'duration_sector_2': 29.134,
#   'duration_sector_3': 42.008,
#   'segments_sector_1': [None, 2048, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2049],
#   'lap_number': 47},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 272,
#   'i2_speed': 268,
#   'st_speed': 308,
#   'date_start': '2025-03-23T08:21:16.159000+00:00',
#   'lap_duration': 97.349,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.138,
#   'duration_sector_2': 29.291,
#   'duration_sector_3': 41.92,
#   'segments_sector_1': [None, 2048, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2049],
#   'lap_number': 48},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 271,
#   'i2_speed': 267,
#   'st_speed': 311,
#   'date_start': '2025-03-23T08:22:53.506000+00:00',
#   'lap_duration': 96.891,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 25.999,
#   'duration_sector_2': 29.144,
#   'duration_sector_3': 41.748,
#   'segments_sector_1': [None, 2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 49},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 272,
#   'i2_speed': 266,
#   'st_speed': 306,
#   'date_start': '2025-03-23T08:24:30.432000+00:00',
#   'lap_duration': 96.779,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 25.917,
#   'duration_sector_2': 29.093,
#   'duration_sector_3': 41.769,
#   'segments_sector_1': [None, 2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 50},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': None,
#   'i2_speed': 266,
#   'st_speed': 312,
#   'date_start': '2025-03-23T08:26:07.333000+00:00',
#   'lap_duration': 96.854,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 25.913,
#   'duration_sector_2': 29.058,
#   'duration_sector_3': 41.883,
#   'segments_sector_1': [None, 2048, 2048, 2051, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 51},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': None,
#   'i2_speed': 264,
#   'st_speed': 307,
#   'date_start': '2025-03-23T08:27:44.075000+00:00',
#   'lap_duration': 96.965,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 25.843,
#   'duration_sector_2': 29.087,
#   'duration_sector_3': 42.035,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 52},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': None,
#   'i2_speed': 262,
#   'st_speed': 308,
#   'date_start': '2025-03-23T08:29:21.108000+00:00',
#   'lap_duration': 97.581,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.082,
#   'duration_sector_2': 29.194,
#   'duration_sector_3': 42.305,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 53},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 270,
#   'i2_speed': 264,
#   'st_speed': 305,
#   'date_start': '2025-03-23T08:30:58.729000+00:00',
#   'lap_duration': 97.092,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 26.047,
#   'duration_sector_2': 29.228,
#   'duration_sector_3': 41.817,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 54},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 264,
#   'i2_speed': 255,
#   'st_speed': 303,
#   'date_start': '2025-03-23T08:32:35.826000+00:00',
#   'lap_duration': 97.429,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 25.916,
#   'duration_sector_2': 29.157,
#   'duration_sector_3': 42.356,
#   'segments_sector_1': [None, 2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2049, 2049, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 55},
#  {'meeting_key': 1255,
#   'session_key': 9998,
#   'driver_number': 55,
#   'i1_speed': 265,
#   'i2_speed': 250,
#   'st_speed': 312,
#   'date_start': '2025-03-23T08:34:13.153000+00:00',
#   'lap_duration': 97.411,
#   'is_pit_out_lap': False,
#   'duration_sector_1': 25.979,
#   'duration_sector_2': 29.255,
#   'duration_sector_3': 42.177,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'lap_number': 56}]

# %%
lap_list = []

for lap in data:
    # Only include laps that have all three sectors
    if all(k in lap for k in ['lap_number', 'segments_sector_1', 'segments_sector_2', 'segments_sector_3']):
        lap_entry = {
            'lap_number': lap['lap_number'],
            'segments_sector_1': lap['segments_sector_1'],
            'segments_sector_2': lap['segments_sector_2'],
            'segments_sector_3': lap['segments_sector_3']
        }
        lap_list.append(lap_entry)

# %%
lap_list
# Out:
# [{'lap_number': 1,
#   'segments_sector_1': [2064, 2049, 2049, 2049, 2049, 2049, 2049],
#   'segments_sector_2': [2049, 2049, 2049, 2049, 2049, 2049],
#   'segments_sector_3': [2049, 2048, 2048, 2048, 2049, 2049, 2049, 2049, 2049]},
#  {'lap_number': 2,
#   'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2048, 2049, 2049, 2049],
#   'segments_sector_3': [2049, 2048, 2048, 2048, 2049, 2049, 2049, 2049, 2049]},
#  {'lap_number': 3,
#   'segments_sector_1': [None, 2049, 2049, 2048, 2049, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2049, 2049, 2048, 2048],
#   'segments_sector_3': [2049, 2048, 2049, 2048, 2049, 2049, 2049, 2049, 2048]},
#  {'lap_number': 4,
#   'segments_sector_1': [2048, 2048, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2048, 2049, 2049, 2049],
#   'segments_sector_3': [2049, 2048, 2048, 2048, 2049, 2051, 2049, 2049, 2049]},
#  {'lap_number': 5,
#   'segments_sector_1': [None, 2048, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2049, 2049, 2048, 2048, 2049, 2048]},
#  {'lap_number': 6,
#   'segments_sector_1': [None, 2049, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2049, 2049, 2048, 2048, 2049, 2048]},
#  {'lap_number': 7,
#   'segments_sector_1': [2049, 2049, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2049, 2048, 2048, 2049, 2049, 2048, 2048, 2048, 2048]},
#  {'lap_number': 8,
#   'segments_sector_1': [2048, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2049]},
#  {'lap_number': 9,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2049, 2049, 2048, 2048, 2048, 2048]},
#  {'lap_number': 10,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2049, 2048]},
#  {'lap_number': 11,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048]},
#  {'lap_number': 12,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2049, 2048, 2048, 2048, 2048, 2048, 2049, 2049, 0]},
#  {'lap_number': 13,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2049]},
#  {'lap_number': 14,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 15,
#   'segments_sector_1': [None, 2048, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2049, 2048, 2048, 2049, 2048, 0]},
#  {'lap_number': 16,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2049, 2064]},
#  {'lap_number': 17,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2049, 2049, 2049, 2048, 2048, 2048, 2048, 2048, 2049]},
#  {'lap_number': 18,
#   'segments_sector_1': [2064, 2064, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2048, 2049, 2049, 2049],
#   'segments_sector_3': [2049, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 19,
#   'segments_sector_1': [2048, 2048, 2049, 2048, 2049, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2048, 2049, 2048, 2049],
#   'segments_sector_3': [2048, 2048, 2048, 2049, 2049, 2048, 2049, 2048, 0]},
#  {'lap_number': 20,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048, 2048]},
#  {'lap_number': 21,
#   'segments_sector_1': [None, 2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048, 2048]},
#  {'lap_number': 22,
#   'segments_sector_1': [None, 2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 23,
#   'segments_sector_1': [None, 2048, 2049, 2051, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 0]},
#  {'lap_number': 24,
#   'segments_sector_1': [None, 2048, 2049, 2048, 2048, 2048, 2049],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 25,
#   'segments_sector_1': [None, 2048, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 26,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048, 0]},
#  {'lap_number': 27,
#   'segments_sector_1': [None, 2048, 2048, 2051, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 28,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2049],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2049]},
#  {'lap_number': 29,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2049]},
#  {'lap_number': 30,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 31,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048, 2048]},
#  {'lap_number': 32,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 33,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 34,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 35,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 0]},
#  {'lap_number': 36,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2049]},
#  {'lap_number': 37,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 38,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 39,
#   'segments_sector_1': [None, 2048, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2049]},
#  {'lap_number': 40,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 41,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 42,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 43,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 0, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048, 2048]},
#  {'lap_number': 44,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2049, 2048, 2049],
#   'segments_sector_3': [2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 45,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 46,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2049, 2048, 2049]},
#  {'lap_number': 47,
#   'segments_sector_1': [None, 2048, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2049]},
#  {'lap_number': 48,
#   'segments_sector_1': [None, 2048, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2049]},
#  {'lap_number': 49,
#   'segments_sector_1': [None, 2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 50,
#   'segments_sector_1': [None, 2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 51,
#   'segments_sector_1': [None, 2048, 2048, 2051, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 52,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2049, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 53,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 54,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2049, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 55,
#   'segments_sector_1': [None, 2048, 2048, 2049, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2049, 2048, 2048, 2048, 2048],
#   'segments_sector_3': [2048, 2049, 2049, 2048, 2048, 2048, 2048, 2048, 2048]},
#  {'lap_number': 56,
#   'segments_sector_1': [None, 2048, 2048, 2048, 2048, 2048, 2048],
#   'segments_sector_2': [2048, 2048, 2048, 2049, 2048, 2048],
#   'segments_sector_3': [2048, 2048, 2048, 2048, 2048, 2048, 2048, 2048]}]

# %%
my_dict = {}

for i in range(2,10):

    response = urlopen(f'https://api.openf1.org/v1/laps?session_key=latest&driver_number=55&lap_number=2')
    data = json.loads(response.read().decode('utf-8'))
    # Option 1: Use a dictionary
    my_dict.update({data[0]["lap_number"]: data[0]["lap_duration"]})

print(data)
# Out:
# [{'meeting_key': 1255, 'session_key': 9998, 'driver_number': 55, 'i1_speed': 279, 'i2_speed': 271, 'st_speed': 336, 'date_start': '2025-03-23T07:05:26.472000+00:00', 'lap_duration': 99.718, 'is_pit_out_lap': False, 'duration_sector_1': 26.361, 'duration_sector_2': 30.511, 'duration_sector_3': 42.846, 'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048, 2048], 'segments_sector_2': [2049, 2048, 2048, 2049, 2049, 2049], 'segments_sector_3': [2049, 2048, 2048, 2048, 2049, 2049, 2049, 2049, 2049], 'lap_number': 2}]

# %%
import dash
from dash import dcc, html
import plotly.graph_objs as go

# ========== LAP TIME DATA ==========
lap_data = {2: 99.718, 3: 99.27, 4: 98.789, 5: 98.787}

def format_lap_time(seconds):
    minutes = int(seconds // 60)
    secs = int(seconds % 60)
    millis = int((seconds - int(seconds)) * 1000)
    return f"{minutes}:{secs:02d}.{millis:03d}"

lap_numbers = list(lap_data.keys())
lap_times = list(lap_data.values())
formatted_times = [format_lap_time(t) for t in lap_times]

lap_time_trace = go.Scatter(
    x=lap_numbers,
    y=lap_times,
    mode='lines+markers',
    line=dict(color='#E50914', width=3),
    marker=dict(size=8, color='white'),
    name='Lap Duration',
    customdata=list(zip(lap_numbers, formatted_times)),
    hovertemplate="<b>Lap %{customdata[0]}</b><br>Time: %{customdata[1]}<extra></extra>"
)

lap_time_figure = {
    'data': [lap_time_trace],
    'layout': go.Layout(
        paper_bgcolor='#333333',
        plot_bgcolor='#333333',
        font=dict(color='white'),
        title='Lap Times vs. Lap Number',
        xaxis=dict(title='Lap Number', color='white', gridcolor='#555'),
        yaxis=dict(title='Lap Duration (seconds)', color='white', gridcolor='#555'),
        hovermode='closest'
    )
}

# ========== MINI-SECTOR MATRIX DATA ==========
data = [
    {
        'lap_number': 2,
        'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048, 2049, 2049, 2048],
        'segments_sector_2': [2049, 2048, 2048, 2049, 2049, 2049],
        'segments_sector_3': [2049, 2048, 2048, 2048, 2049, 2049]
    },
    {
        'lap_number': 3,
        'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048, 2049, 2049, 2048],
        'segments_sector_2': [2049, 2049, 2051, 2049, 2049, 2048],
        'segments_sector_3': [2049, 2049, 2049, 2049, 2049, 2048]
    },
    {
        'lap_number': 4,
        'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048, 2049, 2049, 2048],
        'segments_sector_2': [2049, 2049, 2051, 2049, 2049, 2048],
        'segments_sector_3': [2049, 2049, 2049, 2049, 2049, 2048]
    },
    {
        'lap_number': 5,
        'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048, 2049, 2049, 2048],
        'segments_sector_2': [2049, 2049, 2051, 2049, 2049, 2048],
        'segments_sector_3': [2049, 2049, 2049, 2049, 2049, 2048]
    },
    {
        'lap_number': 6,
        'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048, 2049, 2049, 2048],
        'segments_sector_2': [2049, 2049, 2051, 2049, 2049, 2048],
        'segments_sector_3': [2049, 2049, 2049, 2049, 2049, 2048]
    },
    {
        'lap_number': 7,
        'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048, 2049, 2049, 2048],
        'segments_sector_2': [2049, 2049, 2051, 2049, 2049, 2048],
        'segments_sector_3': [2049, 2049, 2049, 2049, 2049, 2048]
    }
]

color_map = {
    2048: '#FFFF00',  # Yellow
    2049: '#00FF00',  # Green
    2051: '#8000FF'   # Purple
}

segment_traces = []
for lap in data:
    lap_label = f"Lap {lap['lap_number']}"
    segments = lap['segments_sector_1'] + lap['segments_sector_2'] + lap['segments_sector_3']
    for col_index, seg in enumerate(segments):
        segment_traces.append(
            go.Bar(
                x=[col_index],
                y=[lap_label],
                orientation='h',
                width=1,
                marker=dict(color=color_map.get(seg, 'gray')),
                hovertemplate=f"{lap_label} - Segment {col_index + 1}<br>Code: {seg}<extra></extra>",
                showlegend=False
            )
        )

mini_sector_figure = {
    'data': segment_traces,
    'layout': go.Layout(
        title='Mini-Sector Performance Grid',
        barmode='stack',
        paper_bgcolor='#333333',
        plot_bgcolor='#333333',
        font=dict(color='white'),
        xaxis=dict(title='Mini-Sector Index', showgrid=False, tickfont=dict(color='white')),
        yaxis=dict(title='Lap', showgrid=False, tickfont=dict(color='white')),
        height=80 * len(data),
        margin=dict(t=50, l=60, r=20, b=60)
    )
}

# ========== DASH APP ==========
app = dash.Dash(__name__)
app.title = "F1 Dashboard"

app.layout = html.Div(
    style={'backgroundColor': '#111111', 'padding': '40px', 'fontFamily': 'Arial'},
    children=[
        html.H1("Carlos Sainz Lap Dashboard", style={'color': 'white', 'textAlign': 'center', 'marginBottom': '40px'}),

        html.Div([
            html.Div([
                dcc.Graph(id='lap-time-graph', figure=lap_time_figure)
            ], style={
                'backgroundColor': '#333333',
                'borderRadius': '16px',
                'padding': '20px',
                'marginRight': '20px',
                'flex': '1'
            }),

            html.Div([
                dcc.Graph(id='mini-sector-matrix', figure=mini_sector_figure)
            ], style={
                'backgroundColor': '#333333',
                'borderRadius': '16px',
                'padding': '20px',
                'flex': '1'
            })
        ], style={'display': 'flex', 'flexDirection': 'row'})
    ]
)

# Run the app
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
from dash import dcc, html
import plotly.graph_objs as go

# Input data
data = [
    {
        'lap_number': 2,
        'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048,2049, 2049, 2048],
        'segments_sector_2': [2049, 2048, 2048, 2049, 2049, 2049],
        'segments_sector_3': [2049, 2048, 2048, 2048, 2049, 2049]
    },
    {
        'lap_number': 3,
        'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048,2049, 2049, 2048],
        'segments_sector_2': [2049, 2049, 2051, 2049, 2049, 2048],
        'segments_sector_3': [2049, 2049, 2049, 2049, 2049, 2048]
    },
    {
        'lap_number': 4,
        'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048,2049, 2049, 2048],
        'segments_sector_2': [2049, 2049, 2051, 2049, 2049, 2048],
        'segments_sector_3': [2049, 2049, 2049, 2049, 2049, 2048]
    },
    {
        'lap_number': 5,
        'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048,2049, 2049, 2048],
        'segments_sector_2': [2049, 2049, 2051, 2049, 2049, 2048],
        'segments_sector_3': [2049, 2049, 2049, 2049, 2049, 2048]
    }

]

# Color map for segment codes
color_map = {
    2048: '#FFFF00',  # Yellow
    2049: '#00FF00',  # Green
    2051: '#8000FF'   # Purple
}

# Build plot data
traces = []
for row_index, lap in enumerate(data):
    lap_label = f"Lap {lap['lap_number']}"
    segments = lap['segments_sector_1'] + lap['segments_sector_2'] + lap['segments_sector_3']
    for col_index, seg in enumerate(segments):
        traces.append(
            go.Bar(
                x=[col_index],
                y=[lap_label],
                orientation='h',
                width=1,
                marker=dict(color=color_map.get(seg, 'gray')),
                hovertemplate=f"{lap_label} - Segment {col_index + 1}<br>Code: {seg}<extra></extra>",
                showlegend=False
            )
        )

# Create Dash app
app = dash.Dash(__name__)
app.title = "F1 Mini-Sector Grid"

app.layout = html.Div(
    style={'backgroundColor': '#111111', 'padding': '20px', 'fontFamily': 'Arial'},
    children=[
        html.H1("Mini-Sector Matrix", style={'color': 'white', 'textAlign': 'center'}),

        dcc.Graph(
            id='mini-sector-matrix',
            figure={
                'data': traces,
                'layout': go.Layout(
                    title='Mini-Sector Performance Grid',
                    barmode='stack',
                    paper_bgcolor='#111111',
                    plot_bgcolor='#111111',
                    font=dict(color='white'),
                    xaxis=dict(title='Mini-Sector Index', showgrid=False, tickfont=dict(color='white')),
                    yaxis=dict(title='Lap', showgrid=False, tickfont=dict(color='white')),
                    height=80 * len(data),
                    margin=dict(t=50, l=60, r=20, b=60)
                )
            }
        )
    ]
)

# Run the app
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
from dash import dcc, html
import plotly.graph_objs as go

# ========== LAP TIME DATA ==========
lap_data = {2: 99.718}

def format_lap_time(seconds):
    minutes = int(seconds // 60)
    secs = int(seconds % 60)
    millis = int((seconds - int(seconds)) * 1000)
    return f"{minutes}:{secs:02d}.{millis:03d}"

lap_numbers = list(lap_data.keys())
lap_times = list(lap_data.values())
formatted_times = [format_lap_time(t) for t in lap_times]

lap_time_trace = go.Scatter(
    x=lap_numbers,
    y=lap_times,
    mode='lines+markers',
    line=dict(color='#E50914', width=3),
    marker=dict(size=8, color='white'),
    name='Lap Duration',
    customdata=list(zip(lap_numbers, formatted_times)),
    hovertemplate="<b>Lap %{customdata[0]}</b><br>Time: %{customdata[1]}<extra></extra>"
)

lap_time_figure = {
    'data': [lap_time_trace],
    'layout': go.Layout(
        paper_bgcolor='#111111',
        plot_bgcolor='#111111',
        font=dict(color='white'),
        title='Lap Times vs. Lap Number',
        xaxis=dict(title='Lap Number', color='white', gridcolor='#444'),
        yaxis=dict(title='Lap Duration (seconds)', color='white', gridcolor='#444'),
        hovermode='closest'
    )
}

# ========== MINI-SECTOR MATRIX DATA ==========
data = [
    {
        'lap_number': 2,
        'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048, 2049, 2049, 2048],
        'segments_sector_2': [2049, 2048, 2048, 2049, 2049, 2049],
        'segments_sector_3': [2049, 2048, 2048, 2048, 2049, 2049]
    },
    {
        'lap_number': 3,
        'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048, 2049, 2049, 2048],
        'segments_sector_2': [2049, 2049, 2051, 2049, 2049, 2048],
        'segments_sector_3': [2049, 2049, 2049, 2049, 2049, 2048]
    },
    {
        'lap_number': 4,
        'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048, 2049, 2049, 2048],
        'segments_sector_2': [2049, 2049, 2051, 2049, 2049, 2048],
        'segments_sector_3': [2049, 2049, 2049, 2049, 2049, 2048]
    },
    {
        'lap_number': 5,
        'segments_sector_1': [2049, 2049, 2049, 2049, 2049, 2048, 2049, 2049, 2048],
        'segments_sector_2': [2049, 2049, 2051, 2049, 2049, 2048],
        'segments_sector_3': []
    }
]

color_map = {
    2048: '#FFFF00',  # Yellow
    2049: '#00FF00',  # Green
    2051: '#8000FF'   # Purple
}

segment_traces = []
for lap in data:
    lap_label = f"Lap {lap['lap_number']}"
    segments = lap['segments_sector_1'] + lap['segments_sector_2'] + lap['segments_sector_3']
    for col_index, seg in enumerate(segments):
        segment_traces.append(
            go.Bar(
                x=[col_index],
                y=[lap_label],
                orientation='h',
                width=1,
                marker=dict(color=color_map.get(seg, 'gray')),
                hovertemplate=f"{lap_label} - Segment {col_index + 1}<br>Code: {seg}<extra></extra>",
                showlegend=False
            )
        )

mini_sector_figure = {
    'data': segment_traces,
    'layout': go.Layout(
        title='Mini-Sector Performance Grid',
        barmode='stack',
        paper_bgcolor='#111111',
        plot_bgcolor='#111111',
        font=dict(color='white'),
        xaxis=dict(title='Mini-Sector Index', showgrid=False, tickfont=dict(color='white')),
        yaxis=dict(title='Lap', showgrid=False, tickfont=dict(color='white')),
        height=80 * len(data),
        margin=dict(t=50, l=60, r=20, b=60)
    )
}

# ========== DASH APP ==========
app = dash.Dash(__name__)
app.title = "F1 Full Dashboard"

app.layout = html.Div(
    style={'backgroundColor': '#111111', 'padding': '20px', 'fontFamily': 'Arial'},
    children=[
        html.H1("F1 Lap Dashboard", style={'color': 'white', 'textAlign': 'center'}),
        
        html.Div([
            dcc.Graph(id='lap-time-graph', figure=lap_time_figure)
        ], style={'marginBottom': '50px'}),

        html.Div([
            dcc.Graph(id='mini-sector-matrix', figure=mini_sector_figure)
        ])
    ]
)

# Run the app
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
